# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
df = pd.read_excel('MS_Financial_Sample')
print(df.tail())

# %%
df.info()

# %%
df.isnull().sum()

# %%
df['Discount Band'] = df['Discount Band'].fillna('No Discount')

# %%
df.columns = df.columns.str.strip()

# %%
from sqlalchemy import create_engine

# %%
engine = create_engine('mysql+pymysql://root:Uttam%239695@localhost:3306/Finance')

# %%
df.to_sql('MS_Financial_Data', con=engine, if_exists='replace', index=False)
